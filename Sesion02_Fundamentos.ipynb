# %%
numero=100
type

# %%
decimal= 3.1416
type(decimal) # float -> numero decimal
# Out:
# float

# %%
logica=True #verdadero
type(logica) # bool -> booleano -> verdadero o falso
# Out:
# bool

# %%
logica=False #false

type(logica) # bool -> booleano -> verdadero o falso
# Out:
# bool

# %%
num1=10
num2=2

# %%
5+11+(12*3)
# Out:
# 52

# %%
num1+num2 #sumar
# Out:
# 12

# %%
num1-num2 #restar
# Out:
# 8

# %%
num1*num2 #producto
# Out:
# 20

# %%
num1/num2 #cocinte o division
# Out:
# 5.0

# %%
# // division entera
# % modulo

# %%
print('Este programa multiplica dos numeros')
str_num1=input( 'Escribe el primer numero: ')
str_num2=input( 'Escribe el segundo numero: ')
int_num1=int(str_num1)
int_num2=int(str_num2)
resultado=int_num1*int_num2
print( 'El resultado de',str_num1, ' x ',str_num2 ' es ',resultado)
# El rsultado de 23 x 6 es 138
# Out:
#   File "<ipython-input-31-fe87bff80c2e>", line 7
#     print( 'El resultado de',str_num1, ' x ',str_num2 ' es ',resultado)
#                                                            ^
# SyntaxError: invalid syntax

# %%
int_num1=int(str_num1)
int_num2=int(str_resultado=int_num

# %%
print( 'El resultado de '+str(int_num1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d2adcda28f1f> in <module>
# ----> 1 print( 'El resultado de '+str(int_num1))
#
# NameError: name 'int_num1' is not defined

# %%
print('El resultado de {} x {} es'.format(int_num1. int_num2,resultado))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b5f02f7be34f> in <module>
# ----> 1 print('El resultado de {} x {} es'.format(int_num1. int_num2,resultado))
#
# NameError: name 'int_num1' is not defined

# %%
print('Este programa multiplica dos numeros')
str_num1=int( 'Escribe el primer numero: ')
str_num2=int( 'Escribe el segundo numero: ')
print('El resultado de {} x {} es {}') format(num1,num2,num1*num2)
# Out:
#   File "<ipython-input-35-9fbec5d1593c>", line 4
#     print('El resultado de {} x {} es {}') format(num1,num2,num1*num2)
#                                                 ^
# SyntaxError: invalid syntax

# %%
print('Esta es una calculadora')
print('Elije el tipo de operacion del menu')
print('1. Sumar')
print('2. Restar')
print('3. Multiplicar')
print('4. Dvidir')
res=input('¿que quieres hacer? ')
num1=float(input('Escribe el primero numero '))
num2=float(input('Escribe el segundo numero '))
if res=='sumar':
  print('{} + {} = {}'.format(num1,num2,num1+num2))
elif res=='restar':
  print('{} - {} = {}'.format(num1,num2,num1+num2))
elif res=='multiplicar':
  print('{} * {} = {}'.format(num1,num2,num1+num2))
elif res=='dividir':
  print('{} / {} = {}'.format(num1,num2,num1+num2))
else:
  print('Comando no valido')
# Out:
# Esta es una calculadora
# Elije el tipo de operacion del menu
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dvidir
# ¿que quieres hacer? dividir
# Escribe el primero numero10 10
# Escribe el segundo numero5 5
# 10.0 / 5.0 = 15.0

# %%
num1=10
num2=3
if num1==num2:
  print('son iguales')
elif num1>num2:
  print('El primero es mayor')
elif num1<num2:
  print('El segunfo es mayor')
# else es opcional
# Out:
# El primero es mayor

# %%
num1=10
num2=11
if num1!=num2:
  print('No son iguales')
else:print('son iguales')
# Out:
# No son iguales

# %%
num1=10
num2=10
if num1!=num2:
  print('Son diferentes')
elif num1>=num2:
  print('El primero es mayor o igual que el segundo')
elif num1==num2:
  print('Son iguales')
else:
  print('Ninguna condicion')
# Out:
# El primero es mayor o igual que el segundo

# %%
num1=10
num2=10
if num1!=num2:
  print('Son diferentes')
if num1>=num2:
  print('El primero es mayor o igual que el segundo')
if num1==num2:
  print('Son iguales')
else:
  print('Ninguna condicion')
# Out:
# El primero es mayor o igual que el segundo
# Son iguales

# %%
usuario_db='Miguel'
contraseña='qwerty'
print('Log in')
usuario_ingresado=input('Nombre de usuario:')
contraseña_ingresada=input('Contraseña:')
if usuario_ingresado==usuario_db:
  print('Usuario encontrado')
  if contraseña_ingresada==contraseña_db:
  print('La contraseña coincide')
  print('Entraste al sistema')
else:
  print('La contraseña no coincide')
else:
  print('Usuario no encontrado')
# Out:
#   File "<ipython-input-17-603fdc1f9fff>", line 9
#     print('La contraseña coincide')
#         ^
# IndentationError: expected an indented block

# %%
# Seleccion 'if', 'elif' y 'else'
if 10>5:
    print('Verdadero')
  else:
    print('Falso')
# Out:
#   File "<tokenize>", line 4
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
var='Miguel'
if var=='Daniel':
  print('eres Daniel')
elif var=='Miguel':
    print('Eres Miguel')
else:
    print('No eres Daniel ni Miguel')
# Out:
# Eres Miguel

# %%
# 1+2+3+4+5...+98+99+100=?
# for
# suma=1+2+3+4...+99+100

# %%
for i in range(10):
  print("El valor de i es",i)
# Out:
# El valor de i es 0
# El valor de i es 1
# El valor de i es 2
# El valor de i es 3
# El valor de i es 4
# El valor de i es 5
# El valor de i es 6
# El valor de i es 7
# El valor de i es 8
# El valor de i es 9

# %%
for j in range(5):
  print("El valor de j es",j)
# Out:
# El valor de j es 0
# El valor de j es 1
# El valor de j es 2
# El valor de j es 3
# El valor de j es 4

# %%
suma=0
for i in range(100):
  suma=suma+(i+1)
  #print(i+1)
print(suma)
# suma=6,   i=2,i+1+1=3
# Out:
# 5050

# %%
for i in range(5,10):
  print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(10,16):
  print(i)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
for i in range(1,21,5):
  print(i)
# Out:
# 1
# 6
# 11
# 16

# %%
#100+101+102+...+199+200=?
suma=0
for i in range(100,201):
  suma=suma+i
print(suma)
# Out:
# 15150

# %%
# un programa donde le piden al usuario el limite superior
# para realizar la suma partiendo desde cero y hasta llegar
# al limite superior
# si el usuario me dice que el limite superior es 145
# suma de 1+2+3+4+...+145

# %%
limite=int(input('Escribe el limite superior:'))
suma=0
for i in range(1,limite+1):
  suma+=i #suma=suma+i
print(suma)
# Out:
# Escribe el limite superior:100
# 5050

# %%
9/4
# Out:
# 2.25

# %%
9//4
# Out:
# 2

# %%
9%4 #modulo
# 4+4=8
#4+4+4=12
# Out:
# 1

# %%
9%5
# Out:
# 4

# %%
print('Este programa suma numeros pares')
print('En un rango desde 1 hasta el que nos diga')
print('el usuario.')
#2+4+6+8+10...+par del limite superior
limite=int(input('Escribe el limite superior:'))
suma=0
for i in range(1,limite+1):
  if i%2==0:
    suma+=i #suma=suma+i
print(suma)
# Out:
# Este programa suma numeros pares
# En un rango desde 1 hasta el que nos diga
# el usuario.
# Escribe el limite superior:10
# 30
